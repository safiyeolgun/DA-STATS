# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('e_commerce_data.csv', sep= ';')
df
# Out:
#         Ord_ID    Cust_ID  Prod_ID   Ship_ID  Order_Date   Ship_Date  \
# 0      Ord_738   Cust_241   Prod_7  SHP_1005  2012-07-28  2012-07-29
# 1      Ord_757   Cust_231  Prod_14  SHP_1034  2010-01-14  2010-01-16
# 2      Ord_825   Cust_247  Prod_14  SHP_1132  2011-01-10  2011-01-12
# 3     Ord_1092  Cust_1426   Prod_7  SHP_1508  2010-09-05  2010-09-05
# 4     Ord_1286   Cust_481   Prod_7  SHP_1774  2009-10-21  2009-10-23
# ...        ...        ...      ...       ...         ...         ...
# 8098  Ord_3902  Cust_1336  Prod_11  SHP_5415  2012-06-14  2012-06-14
# 8099  Ord_3935  Cust_1333  Prod_17  SHP_5465  2010-09-29  2010-09-29
# 8100  Ord_3937  Cust_1334  Prod_17  SHP_5470  2009-03-09  2009-03-13
# 8101  Ord_3978  Cust_1370  Prod_15  SHP_5529  2012-11-24  2012-11-28
# 8102  Ord_3978  Cust_1370   Prod_2  SHP_5529  2012-11-24  2012-11-28
#
#          Customer_Name          Province    Region Customer_Segment    Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8103 entries, 0 to 8102
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ord_ID                8103 non-null   object
#  1   Cust_ID               8103 non-null   object
#  2   Prod_ID               8103 non-null   object
#  3   Ship_ID               8103 non-null   object
#  4   Order_Date            8103 non-null   object
#  5   Ship_Date             8103 non-null   object
#  6   Customer_Name         8103 non-null   object
#  7   Province              8103 non-null   object
#  8   Region                8103 non-null   object
#  9   Customer_Segment      8103 non-null   object
#  10  Sales                 8103 non-null   int64
#  11  Order_Quantity        8103 non-null   int64
#  12  Order_Priority        8103 non-null   object
#  13  DaysTakenForShipping  8103 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 886.4+ KB

# %%
df.tail()
# Out:
#         Ord_ID    Cust_ID  Prod_ID   Ship_ID  Order_Date   Ship_Date  \
# 8098  Ord_3902  Cust_1336  Prod_11  SHP_5415  2012-06-14  2012-06-14
# 8099  Ord_3935  Cust_1333  Prod_17  SHP_5465  2010-09-29  2010-09-29
# 8100  Ord_3937  Cust_1334  Prod_17  SHP_5470  2009-03-09  2009-03-13
# 8101  Ord_3978  Cust_1370  Prod_15  SHP_5529  2012-11-24  2012-11-28
# 8102  Ord_3978  Cust_1370   Prod_2  SHP_5529  2012-11-24  2012-11-28
#
#          Customer_Name     Province  Region Customer_Segment    Sales  \
# 8098      NEIL KNUDSON  SASKACHEWAN  PRARIE        CORPORATE    41844
# 8099  LYCORIS SAUNDERS  SASKACHEWAN  PRARIE        CORPORATE   345185
# 8100  MAXWELL SCHWARTZ  SASKACHEWAN  PRARIE        CORPORATE  1221543
# 8101      LARRY BLACKS  SASKACHEWAN  PRARIE         CONSUMER   146533
# 8102      LARRY BLACKS  SASKACHEWAN  PRARIE         CONSUMER     4266
#
#       Order_Quantity Order_Priority  DaysTakenForShipping
# 8098              12         MEDIUM                     0
# ...

# %%
df.Sales.value_counts().head(20)
# Out:
# Sales
# 7402        4
# 15119       3
# 2019        3
# 22458       3
# 8989        3
# 17344       3
# 6803        3
# 22062021    3
# 11581       3
# 6429        3
# 1936        3
# 4329        3
# 12756       3
# 1101948     3
# 1587        2
# 19429       2
# 16172       2
# 50764       2
# 23029       2
# 10594       2
# Name: count, dtype: int64

# %%
df.	Ord_ID.value_counts()
# Out:
# Ord_ID
# Ord_1234    5
# Ord_2894    5
# Ord_2506    5
# Ord_2164    5
# Ord_2370    5
#            ..
# Ord_3510    1
# Ord_3660    1
# Ord_3909    1
# Ord_3927    1
# Ord_3935    1
# Name: count, Length: 5506, dtype: int64

# %%
df.Sales.value_counts().tail(7558)
# Out:
# Sales
# 176564     1
# 481412     1
# 32121      1
# 7158       1
# 1971       1
#           ..
# 8733       1
# 87048      1
# 4694       1
# 1031977    1
# 146533     1
# Name: count, Length: 7558, dtype: int64

# %%
df.loc[df.Ord_ID == 'Ord_1234' ]
# Out:
#         Ord_ID   Cust_ID  Prod_ID   Ship_ID  Order_Date   Ship_Date  \
# 570   Ord_1234  Cust_466   Prod_9  SHP_1705  2010-10-23  2010-10-27
# 1504  Ord_1234  Cust_466   Prod_1  SHP_1705  2010-10-23  2010-10-27
# 3252  Ord_1234  Cust_466  Prod_13  SHP_1705  2010-10-23  2010-10-27
# 7383  Ord_1234  Cust_466  Prod_15  SHP_1705  2010-10-23  2010-10-27
# 7384  Ord_1234  Cust_466   Prod_2  SHP_1705  2010-10-23  2010-10-27
#
#         Customer_Name Province   Region Customer_Segment   Sales  \
# 570   RITSA HIGHTOWER  ONTARIO  ONTARIO        CORPORATE   21735
# 1504  RITSA HIGHTOWER  ONTARIO  ONTARIO        CORPORATE  274657
# 3252  RITSA HIGHTOWER  ONTARIO  ONTARIO        CORPORATE    2059
# 7383  RITSA HIGHTOWER  ONTARIO  ONTARIO        CORPORATE  223776
# 7384  RITSA HIGHTOWER  ONTARIO  ONTARIO        CORPORATE   28174
#
#       Order_Quantity Order_Priority  DaysTakenForShipping
# 570               23            LOW                     4
# ...

# %%
df.loc[df.Cust_ID=='Cust_657']
# Out:
#         Ord_ID   Cust_ID  Prod_ID   Ship_ID  Order_Date   Ship_Date  \
# 185   Ord_1866  Cust_657   Prod_4  SHP_2561  2009-06-02  2009-06-03
# 186   Ord_1866  Cust_657   Prod_9  SHP_2561  2009-06-02  2009-06-03
# 2641  Ord_1864  Cust_657   Prod_3  SHP_2558  2010-01-08  2010-01-10
# 3141  Ord_1871  Cust_657   Prod_4  SHP_2569  2010-01-02  2010-01-04
# 3142  Ord_1871  Cust_657   Prod_9  SHP_2569  2010-01-02  2010-01-04
# 3441  Ord_1869  Cust_657   Prod_4  SHP_2566  2010-07-25  2010-07-25
# 7377  Ord_1869  Cust_657  Prod_15  SHP_2566  2010-07-25  2010-07-25
#
#           Customer_Name     Province    Region Customer_Segment     Sales  \
# 185   ELPIDA RITTENBACH  NOVA SCOTIA  ATLANTIC         CONSUMER  26907515
# 186   ELPIDA RITTENBACH  NOVA SCOTIA  ATLANTIC         CONSUMER     47753
# 2641  ELPIDA RITTENBACH  NOVA SCOTIA  ATLANTIC         CONSUMER      8861
# 3141  ELPIDA RITTENBACH  NOVA SCOTIA  ATLANTIC         CONSUMER  12887785
# ...

# %%
for i in df.Cust_ID.unique():
    print(i)
# Out:
# Cust_241
# Cust_231
# Cust_247
# Cust_1426
# Cust_481
# Cust_511
# Cust_518
# Cust_103
# Cust_492
# Cust_595
# Cust_659
# Cust_42
# Cust_812
# Cust_56
# Cust_879
# Cust_8
# Cust_237
# Cust_62
# Cust_356
# Cust_360
# Cust_365
# Cust_155
# Cust_496
# Cust_639
# Cust_449
# Cust_451
# Cust_254
# Cust_264
# Cust_232
# Cust_239
# Cust_240
# Cust_273
# Cust_283
# Cust_298
# Cust_302
# Cust_319
# Cust_69
# Cust_349
# Cust_380
# Cust_79
# Cust_439
# Cust_1037
# Cust_281
# Cust_308
# Cust_307
# Cust_70
# Cust_397
# Cust_195
# Cust_330
# Cust_343
# Cust_72
# Cust_362
# Cust_394
# Cust_65
# Cust_419
# Cust_1421
# Cust_464
# Cust_475
# Cust_1761
# Cust_1064
# Cust_413
# Cust_414
# Cust_442
# Cust_444
# Cust_85
# Cust_472
# Cust_1746
# Cust_198
# Cust_327
# Cust_423
# Cust_471
# Cust_507
# Cust_541
# Cust_535
# Cust_517
# Cust_577
# Cust_598
# Cust_609
# Cust_965
# Cust_1016
# Cust_1008
# Cust_1030
# Cust_1200
# Cust_1184
# Cust_1140
# Cust_1142
# Cust_1210
# Cust_145
# Cust_1260
# Cust_1803
# ...

# %%
len('NOT SPECIFIED')
# Out:
# 13
