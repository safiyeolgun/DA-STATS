# %% [markdown]
# <a href="https://colab.research.google.com/github/safiyeolgun/DA-STATS/blob/main/car_crashes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("car_crashes")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.sample(10)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 15   15.7     2.669    3.925          15.229       13.659       649.06
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 19   15.1     5.738    4.530          13.137       12.684       661.88
# 50   17.4     7.308    5.568          14.094       15.660       791.14
# 13   12.8     4.608    4.352          12.032       12.288       803.11
# 14   14.5     3.625    4.205          13.775       13.775       710.46
#
#     ins_losses abbrev
# 9       144.18     FL
# 44      109.48     UT
# 15      114.47     IA
# 41       96.87     SD
# 42      155.57     TN
# 11      120.92     HI
# 19       96.57     ME
# ...

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %% [markdown]
# Hangi eyalette (abbrev) sigorta primlerinin(ins_premium) en fazla

# %%
df.groupby('abbrev').ins_premium.value_counts()
# Out:
# abbrev  ins_premium
# AK      1053.48        1
# AL      784.55         1
# AR      827.34         1
# AZ      899.47         1
# CA      878.41         1
# CO      835.50         1
# CT      1068.73        1
# DC      1273.89        1
# DE      1137.87        1
# FL      1160.13        1
# GA      913.15         1
# HI      861.18         1
# IA      649.06         1
# ID      641.96         1
# IL      803.11         1
# IN      710.46         1
# KS      780.45         1
# KY      872.51         1
# LA      1281.55        1
# MA      1011.14        1
# MD      1048.78        1
# ME      661.88         1
# MI      1110.61        1
# MN      777.18         1
# MO      790.32         1
# MS      896.07         1
# MT      816.21         1
# NC      708.24         1
# ND      688.75         1
# NE      732.28         1
# NH      746.54         1
# NJ      1301.52        1
# NM      869.85         1
# NV      1029.87        1
# NY      1234.31        1
# OH      697.73         1
# ...

# %%
df.groupby('abbrev').ins_premium.describe()
# Out:
#         count     mean  std      min      25%      50%      75%      max
# abbrev
# AK        1.0  1053.48  NaN  1053.48  1053.48  1053.48  1053.48  1053.48
# AL        1.0   784.55  NaN   784.55   784.55   784.55   784.55   784.55
# AR        1.0   827.34  NaN   827.34   827.34   827.34   827.34   827.34
# AZ        1.0   899.47  NaN   899.47   899.47   899.47   899.47   899.47
# CA        1.0   878.41  NaN   878.41   878.41   878.41   878.41   878.41
# CO        1.0   835.50  NaN   835.50   835.50   835.50   835.50   835.50
# CT        1.0  1068.73  NaN  1068.73  1068.73  1068.73  1068.73  1068.73
# DC        1.0  1273.89  NaN  1273.89  1273.89  1273.89  1273.89  1273.89
# DE        1.0  1137.87  NaN  1137.87  1137.87  1137.87  1137.87  1137.87
# FL        1.0  1160.13  NaN  1160.13  1160.13  1160.13  1160.13  1160.13
# GA        1.0   913.15  NaN   913.15   913.15   913.15   913.15   913.15
# HI        1.0   861.18  NaN   861.18   861.18   861.18   861.18   861.18
# ...

# %%
max(df.ins_premium)
df.ins_premium.max()
# Out:
# 1301.52

# %%
min(df.ins_premium)
df.ins_premium.min()
# Out:
# 641.96

# %%
df.groupby('abbrev')['ins_premium'].mean().sort_values(ascending=False).reset_index()
# Out:
#    abbrev  ins_premium
# 0      NJ      1301.52
# 1      LA      1281.55
# 2      DC      1273.89
# 3      NY      1234.31
# 4      FL      1160.13
# 5      RI      1148.99
# 6      DE      1137.87
# 7      MI      1110.61
# 8      CT      1068.73
# 9      AK      1053.48
# 10     MD      1048.78
# 11     NV      1029.87
# 12     MA      1011.14
# 13     TX      1004.75
# 14     WV       992.61
# 15     GA       913.15
# 16     PA       905.99
# 17     AZ       899.47
# 18     MS       896.07
# 19     WA       890.03
# 20     OK       881.51
# 21     CA       878.41
# 22     KY       872.51
# 23     NM       869.85
# 24     HI       861.18
# 25     SC       858.97
# 26     CO       835.50
# 27     AR       827.34
# 28     MT       816.21
# 29     UT       809.38
# 30     OR       804.71
# 31     IL       803.11
# 32     WY       791.14
# 33     MO       790.32
# 34     AL       784.55
# 35     KS       780.45
# 36     MN       777.18
# 37     VA       768.95
# 38     TN       767.91
# ...

# %%
sns.histplot(x = 'ins_premium', data = df);

# %%
df.loc[df['abbrev'] == 'NJ']
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
#
#     ins_losses abbrev
# 30      159.85     NJ

# %%
df.loc[df['abbrev'] == 'IL']
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 13   12.8     4.608    4.352          12.032       12.288       803.11
#
#     ins_losses abbrev
# 13      139.15     IL

# %%
sns.barplot(x = 'abbrev', y ='ins_premium', data= df,  order=df.sort_values('ins_premium', ascending = False).abbrev);

# %%
df.groupby('abbrev')['ins_losses'].mean().sort_values(ascending=False).reset_index()
# Out:
#    abbrev  ins_losses
# 0      LA      194.78
# 1      MD      192.70
# 2      OK      178.86
# 3      CT      167.02
# 4      CA      165.63
# 5      NJ      159.85
# 6      TX      156.83
# 7      MS      155.77
# 8      TN      155.57
# 9      PA      153.86
# 10     VA      153.72
# 11     WV      152.56
# 12     MI      152.26
# 13     DE      151.48
# 14     NY      150.01
# 15     RI      148.58
# 16     AL      145.08
# 17     MO      144.45
# 18     FL      144.18
# 19     GA      142.80
# 20     AR      142.39
# 21     CO      139.91
# 22     IL      139.15
# 23     NV      138.71
# 24     KY      137.13
# 25     DC      136.05
# 26     MA      135.63
# 27     AK      133.93
# 28     KS      133.80
# 29     OH      133.52
# 30     MN      133.35
# 31     NC      127.82
# 32     WY      122.04
# 33     HI      120.92
# 34     NM      120.75
# 35     NH      120.21
# 36     SC      116.29
# 37     NE      114.82
# 38     IA      114.47
# 39     WA      111.62
# ...

# %%
sns.scatterplot(x = 'ins_losses', y = 'ins_premium', data = df);

# %%
sns.boxplot(x = 'ins_losses', data = df) ;

# %%
sns.boxplot(x = 'ins_premium', data = df) ;

# %%
df['ins_losses'].corr(df['ins_premium'])
# Out:
# 0.6231164385197064

# %%
df['speeding'].corr(df['ins_premium'])
# Out:
# -0.0776746578887178

# %%
df['ins_losses'].corr(df['speeding'])
# Out:
# -0.06592781347567782

# %%
df.corr()
# Out:
# <ipython-input-50-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...
